# %%
import pandas as pd
import os
import fnmatch
data_path = '/Users/serenay/Documents/HateLab/footballer_project/data/collection/footballer_data_d2/'
df = pd.read_csv(data_path + "@sterling7_new.csv", lineterminator="\n" )

df.info()
# df.head()
# Out:
# /Users/serenay/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 581688 entries, 0 to 581687
# Data columns (total 40 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       581688 non-null  int64
#  1   Unnamed: 0.1     581688 non-null  int64
#  2   id               581688 non-null  int64
#  3   conversation_id  581688 non-null  int64
#  4   created_at       581688 non-null  float64
#  5   date             581688 non-null  object
#  6   timezone         581688 non-null  int64
#  7   place            164 non-null     object
#  8   tweet            581688 non-null  object
#  9   language         581688 non-null  object
#  10  hashtags         581688 non-null  object
# ...

# %%
df1 = pd.read_csv(data_path + "@rekeemharper8.csv", lineterminator="\n" )
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18444 entries, 0 to 18443
# Data columns (total 39 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       18444 non-null  int64
#  1   id               18444 non-null  int64
#  2   conversation_id  18444 non-null  int64
#  3   created_at       18444 non-null  float64
#  4   date             18444 non-null  object
#  5   timezone         18444 non-null  int64
#  6   place            0 non-null      float64
#  7   tweet            18444 non-null  object
#  8   language         18444 non-null  object
#  9   hashtags         18444 non-null  object
#  10  cashtags         18444 non-null  object
#  11  user_id          18444 non-null  int64
#  12  user_id_str      18444 non-null  int64
#  13  username         18444 non-null  object
#  14  name             18444 non-null  object
#  15  day              18444 non-null  int64
#  16  hour             18444 non-null  int64
# ...

# %%
df.columns[df.isnull().all()]
# Out:
# Index(['place', 'near', 'geo', 'source', 'user_rt_id', 'user_rt', 'retweet_id',
#        'retweet_date', 'translate', 'trans_src', 'trans_dest'],
#       dtype='object')

# %%
files = os.listdir(data_path)
print(files)
# Out:
# ['@rekeemharper8.csv', '@rubey_lcheek.csv', '@hallerseb.csv', '.DS_Store', '@stevenbergwijn.csv', '@kongoloterence.csv', '@wesley_fofanaa.csv', '@wes5l1nk.csv', '@reecejames_24.csv', '@trentaa98.csv', '@mahrez22.csv', '@benrahma2.csv', '@raphinhab11_.csv', '@smane_officiel.csv', '@mitchelltyrick.csv', '@official_tyro.csv', '@tanguyndombele.csv', '@roberto_firmino.csv', '@virgilvdijk.csv', '@williamsaliba5.csv', '@takumina0116.csv', '@robertportero97.csv', '@richarlison97.csv', '@semiajayi.csv', '@yan_valery.csv', '@reissnelson9.csv', '@wesleymoraes09.csv', '@wilfriedzaha.csv', '@wes_foderingham.csv', '@theowalcott.csv', '@tedenmengi.csv', '@rhianbrewster9.csv', '@yves_bissouma.csv', '@tyrese_francois.csv', '@romainesawyers.csv', '@hm_sin7.csv', '@tsilva3.csv', '@ryanfredericks_.csv', '@sterling7_new.csv', '@willianborges88.csv', '@thomaspartey22.csv', '@trezeguet.csv', '@serge_aurier.csv', '@zackstef_23.csv', '@ryanbertrand3.csv', '@tfosumensah.csv', '@yannickbolasie.csv', '@tammyabr
# ...

# %%
match_file = fnmatch.filter(files, '@*.csv')
print(match_file)

for file in match_file:
    path = data_path + file
    df = pd.read_csv(path, lineterminator="\n")
    x=df.columns[df.isnull().all()]
    print(x.value_counts().sum())
    print(f'{file}')
    print(x)
# Out:
# ['@rekeemharper8.csv', '@rubey_lcheek.csv', '@hallerseb.csv', '@stevenbergwijn.csv', '@kongoloterence.csv', '@wesley_fofanaa.csv', '@wes5l1nk.csv', '@reecejames_24.csv', '@trentaa98.csv', '@mahrez22.csv', '@benrahma2.csv', '@raphinhab11_.csv', '@smane_officiel.csv', '@mitchelltyrick.csv', '@official_tyro.csv', '@tanguyndombele.csv', '@roberto_firmino.csv', '@virgilvdijk.csv', '@williamsaliba5.csv', '@takumina0116.csv', '@robertportero97.csv', '@richarlison97.csv', '@semiajayi.csv', '@yan_valery.csv', '@reissnelson9.csv', '@wesleymoraes09.csv', '@wilfriedzaha.csv', '@wes_foderingham.csv', '@theowalcott.csv', '@tedenmengi.csv', '@rhianbrewster9.csv', '@yves_bissouma.csv', '@tyrese_francois.csv', '@romainesawyers.csv', '@hm_sin7.csv', '@tsilva3.csv', '@ryanfredericks_.csv', '@sterling7_new.csv', '@willianborges88.csv', '@thomaspartey22.csv', '@trezeguet.csv', '@serge_aurier.csv', '@zackstef_23.csv', '@ryanbertrand3.csv', '@tfosumensah.csv', '@yannickbolasie.csv', '@tammyabraham.csv', '@
# ...
